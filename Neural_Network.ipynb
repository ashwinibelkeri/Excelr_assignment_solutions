# %%
# Step 1: Load the dataset
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eed55706-d26c-42f1-916a-ca91cd0cba0c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eed55706-d26c-42f1-916a-ca91cd0cba0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Alphabets_data.csv')

# %%
# Display first few rows
df.head()
# Out:
#   letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  xybar  \
# 0      T     2     8      3       5      1     8    13      0      6      6
# 1      I     5    12      3       7      2    10     5      5      4     13
# 2      D     4    11      6       8      6    10     6      2      6     10
# 3      N     7    11      6       6      3     5     9      4      6      4
# 4      G     2     1      3       1      1     8     6      6      6      6
#
#    x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0      10       8      0       8      0       8
# 1       3       9      2       8      4      10
# 2       3       7      3       7      3       9
# 3       4      10      6      10      2       8
# 4       5       9      1       7      5      10

# %%
# Step 2: Explore the data
# Check dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   letter  20000 non-null  object
#  1   xbox    20000 non-null  int64
#  2   ybox    20000 non-null  int64
#  3   width   20000 non-null  int64
#  4   height  20000 non-null  int64
#  5   onpix   20000 non-null  int64
#  6   xbar    20000 non-null  int64
#  7   ybar    20000 non-null  int64
#  8   x2bar   20000 non-null  int64
#  9   y2bar   20000 non-null  int64
#  10  xybar   20000 non-null  int64
#  11  x2ybar  20000 non-null  int64
#  12  xy2bar  20000 non-null  int64
#  13  xedge   20000 non-null  int64
#  14  xedgey  20000 non-null  int64
#  15  yedge   20000 non-null  int64
#  16  yedgex  20000 non-null  int64
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# letter    0
# xbox      0
# ybox      0
# width     0
# height    0
# onpix     0
# xbar      0
# ybar      0
# x2bar     0
# y2bar     0
# xybar     0
# x2ybar    0
# xy2bar    0
# xedge     0
# xedgey    0
# yedge     0
# yedgex    0
# dtype: int64

# %%
# Summary ststistics
df.describe()
# Out:
#                xbox          ybox         width       height         onpix  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
# mean       4.023550      7.035500      5.121850      5.37245      3.505850
# std        1.913212      3.304555      2.014573      2.26139      2.190458
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        3.000000      5.000000      4.000000      4.00000      2.000000
# 50%        4.000000      7.000000      5.000000      6.00000      3.000000
# 75%        5.000000      9.000000      6.000000      7.00000      5.000000
# max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#                xbar          ybar         x2bar         y2bar         xybar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.897600      7.500450      4.628600      5.178650      8.282050
# ...

# %%
# check class distribution
df['letter'].value_counts() # Assuming 'letter' is the target column
# Out:
# letter
# U    813
# D    805
# P    803
# T    796
# M    792
# A    789
# X    787
# Y    786
# N    783
# Q    783
# F    775
# G    773
# E    768
# B    766
# V    764
# L    761
# R    758
# I    755
# O    753
# W    752
# S    748
# J    747
# K    739
# C    736
# H    734
# Z    734
# Name: count, dtype: int64

# %%
# Step 3: preprocess the data
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
# Drop missing values if any
df.dropna(inplace=True)

# %%
# Encode categorical labels
label_encoder = LabelEncoder()
df['letter'] = label_encoder.fit_transform(df['letter'])

# %%
# Separate features and target
x = df.drop(columns=['letter']) # Assuming 'letter' is the target column
y = df['letter']

# %%
# Normalize features
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
# split into train and test sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)
print("Preprocessing completed")
# Out:
# Preprocessing completed

# %%
# Step 4: Build basic ANN model
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Define the model
model = Sequential([Dense(128, activation='relu', input_shape=(x_train.shape[1],)),
                    Dense(64, activation='relu'),
                    Dense(len(label_encoder.classes_), activation='softmax') #Output layer with softmax
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.4505 - loss: 2.0656 - val_accuracy: 0.7832 - val_loss: 0.7713
# Epoch 2/20
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7919 - loss: 0.7163 - val_accuracy: 0.8438 - val_loss: 0.5423
# Epoch 3/20
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8546 - loss: 0.5002 - val_accuracy: 0.8727 - val_loss: 0.4316
# Epoch 4/20
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8827 - loss: 0.3966 - val_accuracy: 0.8873 - val_loss: 0.3681
# Epoch 5/20
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9005 - loss: 0.3318 - val_accuracy: 0.9028 - val_loss: 0.3212
# Epoch 6/20
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9152 - loss: 0.2802 - val_accuracy: 0.9155 - val_loss: 0.2739
# Epoch 7/20
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9316 - loss: 0.2377 - val_accuracy: 0.9250 - val_loss: 0.2491
# Epoch 8/20
# ...

# %%
# Evaluate on test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9514 - loss: 0.1471
# Test Accuracy: 0.9517

# %%
# !pip install keras-tuner --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 4.3 MB/s eta 0:00:00
# ...

# %%
# Step 5:Hyperparameter Tuning
# Using Keras Tuner:
import keras_tuner as kt
def build_model(hp):
    model = Sequential()
    model.add(Dense(hp.Int('units_1', min_value=64, max_value=256, step=64), activation='relu', input_shape=(x_train.shape[1],)))
    model.add(Dense(hp.Int('units_2', min_value=32, max_value=128, step=32), activation='relu'))
    model.add(Dense(len(label_encoder.classes_), activation='softmax'))
    model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', [0.001, 0.01, 0.1])),
    loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model
tuner = kt.RandomSearch(build_model, objective='val_accuracy', max_trials=5)
tuner.search(x_train, y_train, validation_data=(x_test, y_test), epochs=20, batch_size=32)
# Out:
# Trial 5 Complete [00h 00m 48s]
# val_accuracy: 0.04574999958276749
#
# Best val_accuracy So Far: 0.9462500214576721
# Total elapsed time: 00h 04m 03s

# %%
# Get the best model
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Best Hyperparameters: {best_hps.values}")
# Out:
# Best Hyperparameters: {'units_1': 128, 'units_2': 96, 'learning_rate': 0.01}

# %%
# Step 6: Final model evaluation
# Train the best model
best_model = tuner.hypermodel.build(best_hps)
best_model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6320 - loss: 1.2244 - val_accuracy: 0.8530 - val_loss: 0.4594
# Epoch 2/20
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8662 - loss: 0.4257 - val_accuracy: 0.8890 - val_loss: 0.3559
# Epoch 3/20
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9024 - loss: 0.2989 - val_accuracy: 0.8808 - val_loss: 0.4107
# Epoch 4/20
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9020 - loss: 0.3104 - val_accuracy: 0.9045 - val_loss: 0.3157
# Epoch 5/20
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9306 - loss: 0.2238 - val_accuracy: 0.9118 - val_loss: 0.2786
# ...

# %%
# Evaluate
test_loss, test_acc = best_model.evaluate(x_test, y_test)
print(f"Final Test Accuracy after tuning: {test_acc:.4f}")
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9187 - loss: 0.3582
# Final Test Accuracy after tuning: 0.9178
